# %% [markdown]
# # Structural Simplification in Popular Music

# %% [markdown]
# ### Project Overview
# This project explores whether commercially successful songs tend to be shorter, lyrically simpler, and more repetitive than the broader population of Spotify songs. It combines Billboard chart data, Spotify audio features, and song lyrics to investigate the relationship between chart success and structural simplification in popular music.
#
# // To be expanded

# %% [markdown]
# ### Main research question
# Do commercially successful songs tend to be shorter, simpler, and more repetitive than non-charting songs?

# %% [markdown]
# ### Hypotheses
# - **H0**: There is no difference in average song duration between Billboard-charting songs and non-charting Spotify songs.
# - **H1**: Billboard-charting songs are shorter on average than non-charting Spotify songs.
# - **H2**: Billboard-charting songs have more repetitive lyrics than non-charting Spotify songs.
# - **H3**: Billboard-charting songs have lower lexical diversity than non-charting Spotify songs.
# - **H4**: Shorter duration, higher repetition, and lower lexical diversity are associated with chart success.

# %% [markdown]
# Datasets:
# https://www.kaggle.com/datasets/imuhammad/audio-features-and-lyrics-of-spotify-songs/code/data
#
# https://www.kaggle.com/datasets/dhruvildave/billboard-the-hot-100-songs
#
# https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset/code/data

# %% [markdown]
# # Data Exploration

# %% [markdown]
# The first step is to inspect the three datasets in terms of size, available columns, missing values, duplication, and lyrical coverage. This helps determine which sources are most suitable for the main analysis.

# %%
# imports 
import pandas as pd

# %%
spotify = pd.read_csv("spotify_songs.csv")
billboard_charts = pd.read_csv("charts.csv")
music_data = pd.read_csv("dataset.csv")

# %%
print("Spotify data shape:", spotify.shape)
print("Billboard charts data shape:", billboard_charts.shape)
print("Music data shape:", music_data.shape)
# Out:
# Spotify data shape: (18454, 25)
# Billboard charts data shape: (330087, 7)
# Music data shape: (114000, 21)

# %%
print("Spotify columns:", spotify.columns)
print("Billboard charts columns:", billboard_charts.columns)
print("Music data columns:", music_data.columns)
# Out:
# Spotify columns: Index(['track_id', 'track_name', 'track_artist', 'lyrics', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'language'],
#       dtype='str')
# Billboard charts columns: Index(['date', 'rank', 'song', 'artist', 'last-week', 'peak-rank',
#        'weeks-on-board'],
#       dtype='str')
# Music data columns: Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')

# %%
# sample columns from spotify dataset
spotify.sample(5)
# Out:
#                      track_id                            track_name  \
# 10221  4ezxMulRZWUWA875Ckxf3p                           Isle of You
# 4664   1yo16b3u0lptm6Cs7lx4AD                       Fight The Power
# 3834   1nInOsHbtotAmEOQhtvnzP      Stronger (What Doesn't Kill You)
# 1916   0u4kWPHGLCnNhV1OlDxvpD  Rub You The Right Way - J.G. Classic
# 14551  6alCTRgBPoeAFi2N4il9Q4                          Did It Again
#
#          track_artist                                             lyrics  \
# 10221   Christon Gray  Hey Miss Amazing, you blow my mind Beautiful L...
# 4664     Public Enemy  NA Yet our best trained, best educated, best e...
# 3834   Kelly Clarkson  You know the bed feels warmer Sleeping here al...
# 1916      Johnny Gill  Pump up the bass Hey Pump up the bass Pump Pum...
# 14551       Lil Tecca  We love you, Tecca I got a pack, hit 'em and d...
#
#        track_popularity          track_album_id           track_album_name  \
# 10221                29  5SMxQYp21Vf10jlohsJqII     Even With Evil With Me
# 4664                 56  0aFNb4RDk2hmKKLa0bzXNz     Fear Of A Black Planet
# 3834                 73  0VmE95pr5TSpZWucfyhO5e  Stronger (Deluxe Version)
# 1916                  0  1NfhsIEQ82XXqSFAPX5cXJ     Johnny Gill (Expanded)
# 14551                47  65T18oWoikW2MAilg9j8lW          We Love You Tecca
#
#       track_album_release_date               playlist_name  \
# 10221               2011-07-10             Gospel Neo Soul
# 4664                1990-04-10        Minitruckin Playlist
# 3834                2011-10-24  The Sound of Post-Teen Pop
# 1916                1990-04-17               New Jack City
# 14551               2019-08-30                    Sad Trap
#
#                   playlist_id  ... loudness mode  speechiness  acousticness  \
# 10221  2wP2UAYC4Nqb6oUXkMJlAz  ...   -9.426    0       0.0573       0.77000
# 4664   0VVH2Nzj6kBVGK3WIUQMAw  ...  -12.970    1       0.2550       0.00484
# 3834   10FCW9lj0NdeoYI5VVvVtY  ...   -4.282    1       0.0475       0.04600
# 1916   6RLvj5OnEuPzI1P02KwnzK  ...   -9.850    0       0.0538       0.01460
# 14551  7kzKtw5vug3IIxKfLadi8A  ...   -9.929    0       0.1910       0.18500
#
#        instrumentalness  liveness  valence    tempo  duration_ms  language
# 10221          0.000000    0.1530    0.464  132.352       238507        en
# 4664           0.000002    0.5170    0.415  105.974       282640        en
# 3834           0.000000    0.1120    0.684  116.044       221947        en
# 1916           0.009740    0.0527    0.609  111.599       335000        en
# 14551          0.000000    0.1140    0.186  148.775       116240        en
#
# [5 rows x 25 columns]

# %%
# Sample columns from billboard charts dataset
billboard_charts.sample(10)
# Out:
#               date  rank                              song  \
# 243939  1975-02-08    53               Shame, Shame, Shame
# 44193   2013-05-25    94                       High School
# 230651  1977-08-27    52                       Devil's Gun
# 90369   2004-07-17    70                    I Want To Live
# 111580  2000-06-24    81                       I Disappear
# 237724  1976-04-17    38                       Happy Music
# 294943  1965-05-01    57  Somebody Else Is Taking My Place
# 209593  1981-09-12    94                You Make My Dreams
# 285236  1967-03-11    50                        Jimmy Mack
# 127576  1997-05-31    77               One Night At A Time
#
#                                  artist  last-week  peak-rank  weeks-on-board
# 243939              Shirley And Company       64.0         53               5
# 44193   Nicki Minaj Featuring Lil Wayne       89.0         68               6
# 230651                   C.J. & Company       62.0         36              15
# 90369                       Josh Gracin       75.0         70               3
# 111580                        Metallica       76.0         76               7
# 237724                   The Blackbyrds       43.0         38               7
# 294943                       Al Martino       53.0         53               6
# 209593            Daryl Hall John Oates       81.0          5              20
# 285236           Martha & The Vandellas       68.0         50               3
# 127576                    George Strait       68.0         59               9

# %%
# Sample columns form hte music data dataset
music_data.sample(10)
# Out:
#         Unnamed: 0                track_id              artists  \
# 74621        74621  7KF2jnp3QIwcl7QJP5i5nW         Los Hermanos
# 78285        78285  4x6JPITCakOVB58LPv9GRA  Troglauer;Stereoact
# 87174        87174  1jdAzKbRRrIQ3fpodftKfj        Legião Urbana
# 13091        13091  7e2kKEOXRsHJzb2X1uGJwQ     Frankie Knuckles
# 19769        19769  6pba9PrSRk9hfhtav9blTG         Morgan Evans
# 68596        68596  5ng8nlMTWoDyLL5LhiXDxp    Nacho;Los Mendoza
# 35389        35389  44pklUNBAlVDCe4eWsrc5e                 Zezo
# 107382      107382  4sscDOZCkbLSlDqcCgUJnX                 DEVO
# 103961      103961  0gPQTLaqHDgdupKEok7J2x          Craig David
# 60785        60785  5U7gQ28eWDHl3q1a8pLVay         Elephant Man
#
#                             album_name                     track_name  \
# 74621              Bloco Do Eu Sozinho                     Adeus Você
# 78285    Tag am Meer (Stereoact Remix)  Tag am Meer - Stereoact Remix
# 87174                    Mais Do Mesmo              Geração Coca-Cola
# 13091                   Beyond The Mix              Party At My House
# 19769                 Country Car Hits          Country Outta My Girl
# 68596             Para entrar en calor                    Happy Happy
# 35389   Zezo (O Príncipe dos Teclados)          O Que Eu Faço Amanhã?
# 107382               Freedom of Choice                        Whip It
# 103961                   Born to Do It                         7 Days
# 60785                        Good 2 Go        Head Gone / Genie Dance
#
#         popularity  duration_ms  explicit  danceability  energy  ...  \
# 74621           40       178893     False         0.770   0.324  ...
# 78285           33       234375     False         0.728   0.866  ...
# 87174           48       141400     False         0.574   0.890  ...
# 13091           17       305333     False         0.775   0.737  ...
# 19769            0       202613     False         0.448   0.932  ...
# 68596            0       185360     False         0.797   0.795  ...
# 35389           43       182600     False         0.750   0.820  ...
# 107382          65       161133     False         0.780   0.869  ...
# 103961          71       235133     False         0.659   0.812  ...
# 60785           20       230640     False         0.637   0.732  ...
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 74621    -10.911     0       0.0371        0.5490          0.000042    0.1040
# 78285     -6.023     1       0.1740        0.0217          0.000000    0.2740
# 87174     -5.789     0       0.0410        0.0820          0.000000    0.0741
# 13091    -16.082     0       0.0636        0.0147          0.023600    0.0967
# 19769     -4.424     1       0.0976        0.0174          0.000000    0.3470
# 68596     -5.208     0       0.1620        0.4990          0.000000    0.1640
# 35389     -2.627     0       0.0288        0.3480          0.000000    0.1120
# 107382    -7.255     1       0.0517        0.0744          0.004000    0.0621
# 103961    -7.499     0       0.0487        0.2300          0.000000    0.0951
# 60785     -6.869     1       0.3580        0.5600          0.000000    0.0933
#
#         valence    tempo  time_signature    track_genre
# 74621     0.508  104.523               4            mpb
# 78285     0.781  128.019               4          party
# 87174     0.830   97.900               4          r-n-b
# 13091     0.855  118.733               4  chicago-house
# 19769     0.709  187.813               4        country
# 68596     0.897   96.051               4         latino
# 35389     0.579  111.070               4          forro
# 107382    0.957  157.902               4      synth-pop
# 103961    0.888   83.014               4           soul
# 60785     0.963  115.209               4        j-dance
#
# [10 rows x 21 columns]

# %%
# Check for missing values in spotify dataset
spotify.isnull().sum().sort_values(ascending=False)
# Out:
# language                    260
# lyrics                      260
# energy                        0
# duration_ms                   0
# tempo                         0
# valence                       0
# liveness                      0
# instrumentalness              0
# acousticness                  0
# speechiness                   0
# mode                          0
# loudness                      0
# key                           0
# track_id                      0
# track_name                    0
# playlist_subgenre             0
# playlist_genre                0
# playlist_id                   0
# playlist_name                 0
# track_album_release_date      0
# track_album_name              0
# track_album_id                0
# track_popularity              0
# track_artist                  0
# danceability                  0
# dtype: int64

# %%
# Check for missing values in billboard charts dataset
billboard_charts.isnull().sum().sort_values(ascending=False)
# Out:
# last-week         32312
# date                  0
# rank                  0
# song                  0
# artist                0
# peak-rank             0
# weeks-on-board        0
# dtype: int64

# %%
# Check for missing values in music data dataset
music_data.isnull().sum().sort_values(ascending=False)
# Out:
# artists             1
# album_name          1
# track_name          1
# Unnamed: 0          0
# mode                0
# time_signature      0
# tempo               0
# valence             0
# liveness            0
# instrumentalness    0
# acousticness        0
# speechiness         0
# key                 0
# loudness            0
# track_id            0
# energy              0
# danceability        0
# explicit            0
# duration_ms         0
# popularity          0
# track_genre         0
# dtype: int64

# %%
#checking for duplicates in the different datasets
spotify.duplicated().sum()
# Out:
# np.int64(0)

# %%
billboard_charts.duplicated().sum()
# Out:
# np.int64(0)

# %%
music_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
spotify['track_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
music_data['track_id'].duplicated().sum()
# Out:
# np.int64(24259)

# %%
# checking for duplicate song-artist pairs in Spotify dataset
spotify[['track_name', 'track_artist']].duplicated().sum()
# Out:
# np.int64(1862)

# %%
# checking for duplicate song-artist pairs in Billboard
billboard_charts[['song', 'artist']].duplicated().sum()
# Out:
# np.int64(300406)

# %%
((spotify['lyrics'] == 'NA') | (spotify['lyrics'] == 'N/A') | (spotify['lyrics'] == 'NaN')).sum()
# Out:
# np.int64(0)

# %%
(spotify['lyrics'] == 'NaN').sum()
# Out:
# np.int64(0)

# %%
spotify['lyrics'].sample(10)
# Out:
# 2027     NA Si el ritmo te lleva a mover la cabeza Ya e...
# 51       Fuckers in school telling me, always in the ba...
# 11516    I've seen life through the eyes of a different...
# 8539     Because you move me Baby won't you prove me Wr...
# 63       NA Uuh-uh Uuh-uh Uuh-uh Uuh-uh Yeah, mi chiedo...
# 104      Feelin' the song, party done, shadows walkin' ...
# 13466    NA Could it be you calling me down, down, down...
# 8867                                                   NaN
# 17208    I'm lying alone with my head on the phone Thin...
# 11819    I wanted you to know, I love the way you laugh...
# Name: lyrics, dtype: str

# %%
spotify['lyrics'].isna().sum()
# Out:
# np.int64(260)

# %%
spotify['language'].value_counts(dropna=False)
# Out:
# language
# en     15405
# es      1705
# NaN      260
# de       241
# pt       176
# it       133
# pl        76
# nl        72
# fr        65
# tl        63
# da        40
# id        34
# ko        29
# vi        24
# ro        16
# sw        16
# so        16
# cy        12
# no        10
# hi        10
# ja         8
# et         7
# tr         5
# sv         5
# af         5
# ru         4
# sq         3
# hr         3
# ar         2
# cs         2
# ca         2
# el         2
# hu         1
# fi         1
# sk         1
# Name: count, dtype: int64

# %%
spotify[spotify[['track_name', 'track_artist']].duplicated(keep=False)] \
    .sort_values(['track_name', 'track_artist']) \
    [['track_id', 'track_name', 'track_artist', 'playlist_name', 'track_popularity', 'duration_ms']] \
    .head(30)
# Out:
#                      track_id                 track_name  \
# 13914  5xGxl3Iux0worDz9tLbaDn                  #1 Stunna
# 17699  7kBdenpTmgWfAz9clmBcok                  #1 Stunna
# 14354  65NTcXUtOb27NHKQ4fAcw0             '39 - 2011 Mix
# 14560  6aNP9GlBi3VHPXl7w3Qjr9             '39 - 2011 Mix
# 11623  4xkOaSrkexMciUUogZKVTS           'Till I Collapse
# 16450  6yr8GiTHWvFfi4o6Q5ebdT           'Till I Collapse
# 5413   2dLWb2s1QtgpzAGOaBVa0h                 1 Question
# 11397  4UipF3IyxsyStTstiwGHhV                 1 Question
# 9499   41SwdQIX8Hy2u6fuEDgvWr                        10%
# 16030  6Ti0coAmnSsv3Wx09RhoY6                        10%
# 1606   0qgrrDnUUhyxpxbBznUnzg                18 and Life
# 3330   1HlGblweLq0eAwnb0NY1EQ                18 and Life
# 9284   3Y8Ff1nH44jFywAtpgmleZ     1979 - Remastered 2012
# 13408  5QLHGv0DfpeXLNFo7SFEy1     1979 - Remastered 2012
# 11428  4UuHWIkAWnN176A2rx7YFB                       1985
# 13266  5oQcOu1omDykbIPSdSQQNJ                       1985
# 3253   1gnwmsTBXCw5Lyxt1UxM8s  2 Of Amerikaz Most Wanted
# 7469   3a5sW7rqY5b5WDdANvSHxD  2 Of Amerikaz Most Wanted
# 12441  5Ddu4AaN1VaZ1MTg1neCl7  2 Of Amerikaz Most Wanted
# 15924  6S5SJlNXgrUBTLa58NMwGk  2 Of Amerikaz Most Wanted
# 3758   1mQRQlbf1nXbazPEuSyij8                         22
# 14681  6ce41JVa6KFaryfmC2bu2W                         22
# 2565   15gVYensbJgM9QDIFjB01c                  24K Magic
# 14591  6b8Be6ljOzmkOmFslEb23P                  24K Magic
# 11867  51UVuDbX8WqHyn2ga4dsyG                25 Lighters
# 13629  5tlrEiYWEl0fsa6OFoV5EI                25 Lighters
# 3793   1mZF9TEc7gpw7by7NCZSKr                  3 Strikes
# 17356  7FrQfROirwZQH9YPskADJA                  3 Strikes
# 7851   3EVwqtxoYiJmUd1Ennr10W                       6 AM
# 9039   3uvypVUsiIr1B0BccIcsEh                       6 AM
#
#                 track_artist  \
# 13914             Big Tymers
# 17699             Big Tymers
# 14354                  Queen
# 14560                  Queen
# 11623                 Eminem
# 16450                 Eminem
# 5413                    E-40
# 11397                   E-40
# 9499              KAYTRANADA
# 16030             KAYTRANADA
# 1606                Skid Row
# 3330                Skid Row
# 9284   The Smashing Pumpkins
# 13408  The Smashing Pumpkins
# 11428       Bowling For Soup
# 13266       Bowling For Soup
# 3253                    2Pac
# 7469                    2Pac
# 12441                   2Pac
# 15924                   2Pac
# 3758            Taylor Swift
# 14681           Taylor Swift
# 2565              Bruno Mars
# 14591             Bruno Mars
# 11867                 DJ DMD
# 13629                 DJ DMD
# 3793               Terror Jr
# 17356              Terror Jr
# 7851                J Balvin
# 9039                J Balvin
#
#                                            playlist_name  track_popularity  \
# 13914            Dirty South Rap Classics by DJ HOTSAUCE                 0
# 17699                                      Hip-Hop Drive                48
# 14354      I didn’t know perm stood for permanent (wave)                60
# 14560                The Queen - La Discografia Completa                46
# 11623                      Gangster Rap | 100 % Gangster                83
# 16450                                       Gangster Rap                16
# 5413                                            Neo-Soul                51
# 11397                            Chixtape 5 - Tory Lanez                42
# 9499                                  Contemporary Urban                70
# 16030                                    New R&B‏‏​​   ‍                64
# 1606                             Hard Rock Cafe Classics                69
# 3330   Mega Rock Ballads: The Best Slow Rock Compilat...                59
# 9284                                   keg party jukebox                15
# 13408                        The Sound of Permanent Wave                74
# 11428                           Pop Punk | Post-Hardcore                59
# 13266                                     Permanent Wave                69
# 3253                             Oldschool Gangsta Rap 👑                 1
# 7469              90s Gangsta Rap / Top Hip-hop Classics                 1
# 12441                 Southern California Hip Hop Primer                62
# 15924                           Gangsta Rap/90's Hip-Hop                54
# 3758                                   🤩🤪Post Teen Pop🤪🤩                 0
# 14681                                      post teen pop                68
# 2565                   School Dance 2019 (Squeaky Clean)                32
# 14591                                      10er Playlist                78
# 11867                              90's Southern Hip Hop                28
# 13629                                   Southern Hip Hop                 4
# 3793                        The Sound of Indie Poptimism                56
# 17356                                            EDM/POP                 0
# 7851   Hot Latino Mix (Latin, Hip Hop, Rap, RnB, Danc...                 3
# 9039                         Fiesta Latina Mix 🎈🎉💃🏻🕺🏻☀️🏖                70
#
#        duration_ms
# 13914       281960
# 17699       281960
# 14354       210800
# 14560       210800
# 11623       297787
# 16450       297893
# 5413        250081
# 11397       250081
# 9499        186680
# 16030       186684
# 1606        229960
# 3330        231280
# 9284        266200
# 13408       266200
# 11428       193000
# 13266       193000
# 3253        246667
# 7469        246667
# 12441       246533
# 15924       246667
# 3758        231867
# 14681       232120
# 2565        224760
# 14591       225983
# 11867       287467
# 13629       288853
# 3793        175777
# 17356       175901
# 7851        243227
# 9039        243227

# %%
spotify_en = spotify[(spotify['language'] == 'en') & (spotify['lyrics'].notna())].copy()
spotify_en.shape
# Out:
# (15405, 25)

# %%
spotify_en[['track_name', 'track_artist']].duplicated().sum()
# Out:
# np.int64(1679)

# %%
spotify_en_unique = spotify_en.drop_duplicates(subset=['track_name', 'track_artist']).copy()
spotify_en_unique.shape
# Out:
# (13726, 25)

# %%
spotify_en_unique[['track_name', 'track_artist']].duplicated().sum()
# Out:
# np.int64(0)

# %%
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name'].str.lower()
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist'].str.lower()

# %%
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name_norm'].str.replace(r"\(.*?\)", "", regex=True)
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name_norm'].str.replace(r"\[.*?\]", "", regex=True)
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name_norm'].str.replace(r"feat\.?.*", "", regex=True)
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name_norm'].str.replace(r"featuring.*", "", regex=True)
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name_norm'].str.replace(r"ft\.?.*", "", regex=True)
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name_norm'].str.replace(r"[^a-z0-9\s]", "", regex=True)
spotify_en_unique['track_name_norm'] = spotify_en_unique['track_name_norm'].str.replace(r"\s+", " ", regex=True).str.strip()

# %%
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace(r"\(.*?\)", "", regex=True)
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace(r"\[.*?\]", "", regex=True)
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace(r"feat\.?.*", "", regex=True)
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace(r"featuring.*", "", regex=True)
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace(r"ft\.?.*", "", regex=True)
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace("&", "and", regex=False)
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace(r"[^a-z0-9\s]", "", regex=True)
spotify_en_unique['track_artist_norm'] = spotify_en_unique['track_artist_norm'].str.replace(r"\s+", " ", regex=True).str.strip()

# %% [markdown]
# After restricting the Spotify dataset to English-language songs with available lyrics and removing repeated playlist-based entries, 13,734 unique song-artist observations remained. A first exact-match merge with Billboard chart data, using normalized song and artist names, identified 3,063 songs that appeared in Billboard at least once. This corresponds to approximately 22.3% of the cleaned Spotify sample. The result suggests that the merged dataset is suitable for comparing charting and non-charting songs.

# %% [markdown]
# # Data Preparation
#
# In this stage, the Billboard dataset is aggregated from weekly chart observations to song level. This allows each Spotify song to be matched against a single Billboard song record. Song and artist names are normalized in both datasets in order to reduce mismatches caused by punctuation, featured-artist notation, and formatting differences. The merged dataset then includes both a binary charting label `is_charting` and richer success indicators such as peak rank, weeks on board, and chart entries.

# %%
billboard_song_level = (
    billboard_charts.groupby(['song', 'artist'], as_index=False)
    .agg({
        'rank': ['min', 'mean'],
        'peak-rank': 'min',
        'weeks-on-board': 'max',
        'date': ['min', 'max', 'count']
    })
)

# %%
billboard_song_level.columns = [
    'song',
    'artist',
    'best_weekly_rank',
    'avg_weekly_rank',
    'peak_rank',
    'weeks_on_board',
    'first_chart_date',
    'last_chart_date',
    'chart_entries'
]

# %%
billboard_song_level.head()
# Out:
#                                     song  \
# 0                              "B" Girls
# 1  "Cherry Cherry" from Hot August Night
# 2                "Having A Party" Medley
# 3                            "Joy" Pt. I
# 4                         "Roots" Medley
#
#                                     artist  best_weekly_rank  avg_weekly_rank  \
# 0                       Young And Restless                54        71.000000
# 1                             Neil Diamond                31        47.900000
# 2  The Ovations (Featuring Louis Williams)                56        76.000000
# 3                              Isaac Hayes                30        42.222222
# 4                             Quincy Jones                57        70.571429
#
#    peak_rank  weeks_on_board first_chart_date last_chart_date  chart_entries
# 0         54              15       1990-05-05      1990-08-11             15
# 1         31              10       1973-03-17      1973-05-19             10
# 2         56               9       1973-10-13      1973-12-08              9
# 3         30               9       1973-12-22      1974-02-16              9
# 4         57               7       1977-03-05      1977-04-16              7

# %%
billboard_song_level.shape
# Out:
# (29681, 9)

# %%
billboard_song_level['song_norm'] = billboard_song_level['song'].str.lower()
billboard_song_level['artist_norm'] = billboard_song_level['artist'].str.lower()

billboard_song_level['song_norm'] = billboard_song_level['song_norm'].str.replace(r"\(.*?\)", "", regex=True)
billboard_song_level['song_norm'] = billboard_song_level['song_norm'].str.replace(r"\[.*?\]", "", regex=True)
billboard_song_level['song_norm'] = billboard_song_level['song_norm'].str.replace(r"feat\.?.*", "", regex=True)
billboard_song_level['song_norm'] = billboard_song_level['song_norm'].str.replace(r"featuring.*", "", regex=True)
billboard_song_level['song_norm'] = billboard_song_level['song_norm'].str.replace(r"ft\.?.*", "", regex=True)
billboard_song_level['song_norm'] = billboard_song_level['song_norm'].str.replace(r"[^a-z0-9\s]", "", regex=True)
billboard_song_level['song_norm'] = billboard_song_level['song_norm'].str.replace(r"\s+", " ", regex=True).str.strip()

billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace(r"\(.*?\)", "", regex=True)
billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace(r"\[.*?\]", "", regex=True)
billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace(r"feat\.?.*", "", regex=True)
billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace(r"featuring.*", "", regex=True)
billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace(r"ft\.?.*", "", regex=True)
billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace("&", "and", regex=False)
billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace(r"[^a-z0-9\s]", "", regex=True)
billboard_song_level['artist_norm'] = billboard_song_level['artist_norm'].str.replace(r"\s+", " ", regex=True).str.strip()

# %%
spotify_billboard_match = spotify_en_unique.merge(
    billboard_song_level,
    left_on=['track_name_norm', 'track_artist_norm'],
    right_on=['song_norm', 'artist_norm'],
    how='left'
)

# %%
spotify_billboard_match['is_charting'] = spotify_billboard_match['peak_rank'].notna().astype(int)

# %%
spotify_billboard_match['weeks_on_board'] = spotify_billboard_match['weeks_on_board'].fillna(0)
spotify_billboard_match['chart_entries'] = spotify_billboard_match['chart_entries'].fillna(0)

# %%
spotify_billboard_match.sample(10)
# Out:
#                      track_id  \
# 4098   28c4nfBHdb3xviamRCEsIe
# 11181  6crUbvaaSSMuLwgq63Iwdp
# 5353   2V98yEHrGuNclS6TRmuVfG
# 1984   1244xKUG27TnmQhUJlo3gU
# 10567  5we20HGQuDFTnpmOtawm96
# 581    0ELVXVHz8aPgwLySfkDn8e
# 12473  70nmZhHZLNVYWP4NON41Zw
# 9713   5fsjS6L83RSJBqRJKL0BTY
# 2425   1cPBPL1FlwRM7mYXixVmJB
# 12220  6VJ8OvHkzRNLP9x1YHBiSw
#
#                                               track_name       track_artist  \
# 4098                                       Feel the Pain       Dinosaur Jr.
# 11181                                      Memphis to La       Chris Travis
# 5353                                       Kiss And Tell      You Me At Six
# 1984                                             Reapers               Muse
# 10567                                               Ride       Madison Mars
# 581                                               Hey Ya     Obadiah Parker
# 12473               Runnin' Thru The 7th With My Woadies        $uicideBoy$
# 9713                                      Got Your Money  Ol' Dirty Bastard
# 2425                                            Thursday         Leven Kali
# 12220  One Look - Axwell vs Dimitri Vegas & Like Mike...         David Tort
#
#                                                   lyrics  track_popularity  \
# 4098   I feel the pain of everyone Then I feel nothin...                60
# 11181  Never wanted to be, this way I'm stuck now Onl...                37
# 5353   You're so good And you're so bad And everybody...                 0
# 1984   Home, it's becoming a killing field There's a ...                59
# 10567  Call it call it Whatever you wanna Imma rock o...                46
# 581    My baby don't mess around Because she loves me...                 3
# 12473  When you come home, I'll stop this When you co...                72
# 9713   I dedicate this to all the pretty girls All th...                 0
# 2425   You should bring a friend (Bring a friend) She...                52
# 12220  One Look was all it took With a glance, I was ...                20
#
#                track_album_id                  track_album_name  \
# 4098   0yxM1OyaFOZiJhi9eNThE4                   Without a Sound
# 11181  0nz5MBodhuHKUDWvn72TLj                      Never Forget
# 5353   4uC7zTuKQvssFjKEmLB8x3             Take Off Your Colours
# 1984   2wart5Qjnvx1fd7LPdQxgJ                            Drones
# 10567  4hqc7qwVOK7C6hr5a46slt                              Ride
# 581    4xjHVgg9DgYhV1UVJhDlKO               Obadiah Parker Live
# 12473  0zEbhG51umfmVIzSmQk6mK                $outh $ide $uicide
# 9713   2pPNC9cSF3mhMZcT7t3iw7                          The Hits
# 2425   5JWnguoJ3sh94rX6jg9iM8  I Get High When I Think About Us
# 12220  1Vv86uoM5nQziXD41PApJR                          One Look
#
#       track_album_release_date  \
# 4098                1994-08-23
# 11181               2014-05-14
# 5353                      2008
# 1984                2015-06-04
# 10567               2019-02-15
# 581                 2007-01-01
# 12473               2015-09-01
# 9713                      2008
# 2425                2018-12-07
# 12220               2011-03-20
#
#                                            playlist_name  \
# 4098                         The Sound of Permanent Wave
# 11181                                        RAP Gangsta
# 5353                            Pop Punk | Post-Hardcore
# 1984   Muse Radio - (Uprising, Starlight, Supermassiv...
# 10567  Fresh EDM | Progressive House | Electro House ...
# 581                                     Bluegrass Covers
# 12473                                      < DARK TRAP >
# 9713              90s Gangsta Rap / Top Hip-hop Classics
# 2425                                       Neo Soul 2019
# 12220                                     Selected House
#
#                   playlist_id  ... best_weekly_rank avg_weekly_rank  \
# 4098   4EYSGTuqe9cVfSVpX4gtGv  ...              NaN             NaN
# 11181  1Z1gW89x4MSBjkvVjGg7DQ  ...              NaN             NaN
# 5353   1YgWQAs1s77NzieIH4ARKn  ...              NaN             NaN
# 1984   0dAbaJtkS9st5o0cBe1Zcu  ...              NaN             NaN
# 10567  0FCHg9zJMNNiOokh3hVcxd  ...              NaN             NaN
# 581    37i9dQZF1DX56crgoe4TG3  ...              NaN             NaN
# 12473  19WuHd4MxWLzE1fpMmw4S4  ...              NaN             NaN
# 9713   0C2zyPdlkbWHrwVg9gqNdU  ...             33.0           53.65
# 2425   44d7ppo4cggZJmzH2WOhAc  ...              NaN             NaN
# 12220  2JPzPB9jnvJLAYtmCbvZy8  ...              NaN             NaN
#
#        peak_rank  weeks_on_board  first_chart_date  last_chart_date  \
# 4098         NaN             0.0               NaN              NaN
# 11181        NaN             0.0               NaN              NaN
# 5353         NaN             0.0               NaN              NaN
# 1984         NaN             0.0               NaN              NaN
# 10567        NaN             0.0               NaN              NaN
# 581          NaN             0.0               NaN              NaN
# 12473        NaN             0.0               NaN              NaN
# 9713        33.0            20.0        1999-10-23       2000-03-04
# 2425         NaN             0.0               NaN              NaN
# 12220        NaN             0.0               NaN              NaN
#
#        chart_entries       song_norm       artist_norm  is_charting
# 4098             0.0             NaN               NaN            0
# 11181            0.0             NaN               NaN            0
# 5353             0.0             NaN               NaN            0
# 1984             0.0             NaN               NaN            0
# 10567            0.0             NaN               NaN            0
# 581              0.0             NaN               NaN            0
# 12473            0.0             NaN               NaN            0
# 9713            20.0  got your money  ol dirty bastard            1
# 2425             0.0             NaN               NaN            0
# 12220            0.0             NaN               NaN            0
#
# [10 rows x 39 columns]

# %%
spotify_billboard_match.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'lyrics', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'language', 'track_name_norm', 'track_artist_norm',
#        'song', 'artist', 'best_weekly_rank', 'avg_weekly_rank', 'peak_rank',
#        'weeks_on_board', 'first_chart_date', 'last_chart_date',
#        'chart_entries', 'song_norm', 'artist_norm', 'is_charting'],
#       dtype='str')

# %%
spotify_billboard_match = spotify_billboard_match.drop(
    columns=['playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre'],
    errors='ignore'
)

# %%
spotify_billboard_match.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'lyrics', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'language', 'track_name_norm', 'track_artist_norm',
#        'song', 'artist', 'best_weekly_rank', 'avg_weekly_rank', 'peak_rank',
#        'weeks_on_board', 'first_chart_date', 'last_chart_date',
#        'chart_entries', 'song_norm', 'artist_norm', 'is_charting'],
#       dtype='str')

# %%
spotify_billboard_match.to_csv("spotify_billboard_prepared.csv", index=False)

# %%
prepared_data = pd.read_csv("spotify_billboard_prepared.csv")
prepared_data.shape
# Out:
# (13734, 35)

# %% [markdown]
# ### Prepared dataset
#
# The final prepared dataset combines cleaned Spotify song records with Billboard chart-success information. Songs that were matched to Billboard receive chart-performance variables such as `peak_rank`, `weeks_on_board`, and `chart_entries`, while unmatched songs remain in the dataset as non-charting observations. This prepared table is saved as `spotify_billboard_prepared.csv` and will be used in the next stage for feature engineering and statistical analysis.
